# %%
from test_functions import *
# %matplotlib notebook
danilov = lambda x: x[0] + 2*x[1] + 4*np.sqrt(1 + x[0]**2 + x[1]**2)

# %%
plot_2Dfunction(danilov, zlim=[0, 800], xy_range=[-100, 100], quality=100, cmap=cm.turbo, step=0.2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_2Dfunction(ackley, zlim=[0, 15], xy_range=[-3, 3], quality=100, cmap=cm.turbo, step=0.08)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_2Dfunction(rastrigin, zlim=[0, 100], xy_range=[-7, 7], quality=100, cmap=cm.turbo, step=0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_2Dfunction(sphere, zlim=[0, 100], xy_range=[-7, 7], quality=100, cmap=cm.turbo, step=0.05)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_2Dfunction(rozenbrock, zlim=[0, 1000], xy_range=[-1.2, 2], quality=100, cmap=cm.turbo, step=0.01)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_2Dfunction(beale, zlim=[0, 15000], xy_range=[-3.5, 3.5], quality=100, cmap=cm.turbo, step=0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_2Dfunction(goldstein_price, zlim=[0, 50000], xy_range=[-1.5, 1], quality=100, cmap=cm.turbo, step=0.01)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_2Dfunction(booth, zlim=[0, 700], xy_range=[-5, 8], quality=100, cmap=cm.turbo, step=0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_2Dfunction(bukin, zlim=[0, 400], xy_range=[-10.001, 1.1], quality=100, cmap=cm.turbo, step=0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_2Dfunction(himmelblau, zlim=[0, 1500], xy_range=[-5, 5], quality=100, cmap=cm.turbo, step=0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_2Dfunction(eggholder, zlim=[-1000, 1500], xy_range=[200, 700], quality=120, cmap=cm.turbo, step=1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_2Dfunction(cross, zlim=[-5, 5], xy_range=[-5, 5], quality=90, cmap=cm.turbo, step=0.09)
# Out:
# <img src="data:image/png;base64,..." width="640">
